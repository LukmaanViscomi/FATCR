# %% [markdown]
# ### **📓 Notebook: Create_Christian_Creeds_Repo.ipynb**

# %% [markdown]
# ## 🔹 Cell 1 – Load GitHub credentials from Colab secrets

# %%
from google.colab import userdata
import pathlib, os

# 1) Username: just type it here once
GITHUB_USERNAME = "lukmaanViscomi"  # e.g. "lukmaanViscomi"

# 2) Token: read from Colab secret called GITHUB_PAT
GITHUB_TOKEN = userdata.get('GITHUB_PAT')

# 3) Email (optional)
GITHUB_EMAIL = f"{GITHUB_USERNAME}@users.noreply.github.com"

REPO_NAME = "christian-creeds-kb"
REPO_DIR = pathlib.Path("/content") / REPO_NAME

print("GitHub user:", GITHUB_USERNAME)
print("Using local repo dir:", REPO_DIR)

REPO_DIR.mkdir(exist_ok=True)
os.chdir(REPO_DIR)

# Expose to bash
os.environ["GITHUB_USERNAME"] = GITHUB_USERNAME
os.environ["GITHUB_TOKEN"] = GITHUB_TOKEN
os.environ["GITHUB_EMAIL"] = GITHUB_EMAIL
os.environ["REPO_NAME"] = REPO_NAME
# Out:
# GitHub user: lukmaanViscomi
# Using local repo dir: /content/christian-creeds-kb

# %% [markdown]
# ## 🔹 Cell 2 – Create txt/ folder and write the four creed files

# %%
import textwrap
from pathlib import Path

txt_dir = REPO_DIR / "txt"
txt_dir.mkdir(parents=True, exist_ok=True)

apostles = """
I believe in God,
the Father Almighty,
maker of heaven and earth.

I believe in Jesus Christ, his only Son, our Lord;
who was conceived by the Holy Spirit,
born from the virgin Mary,
suffered under Pontius Pilate,
was crucified, died, and was buried;
he descended to the realm of the dead.
On the third day he rose again;
he ascended into heaven
and sits at the right hand of God the Father Almighty;
from there he will come to judge the living and the dead.

I believe in the Holy Spirit;
the one holy universal Church,
the communion of saints,
the forgiveness of sins,
the resurrection of the body,
and the life everlasting. Amen.
"""

nicene = """
We believe in one God,
the Father Almighty,
maker of heaven and earth,
of all things visible and invisible.

And in one Lord Jesus Christ,
the only-begotten Son of God,
begotten from the Father before all ages:
light from light, true God from true God,
begotten, not made,
of one being with the Father;
through him all things came to be.
For us human beings and for our salvation
he came down from heaven,
and by the Holy Spirit was incarnate from the virgin Mary,
and became truly human.
For our sake he was crucified under Pontius Pilate;
he suffered and was buried;
on the third day he rose again,
according to the Scriptures;
he ascended into heaven
and is seated at the right hand of the Father.
He will come again in glory
to judge the living and the dead,
and his kingdom will have no end.

And in the Holy Spirit,
the Lord and life-giver,
who proceeds from the Father,
who with the Father and the Son together
is worshipped and glorified,
who has spoken through the prophets.

We believe in one holy, universal and apostolic Church.
We acknowledge one baptism
for the forgiveness of sins.
We look for the resurrection of the dead
and the life of the age to come. Amen.
"""

athanasian = """
Whoever desires to be saved
must before all things hold the universal Christian faith.
Whoever does not keep this faith whole and undefiled
will without doubt perish eternally.

Now the universal faith is this:
that we worship one God in Trinity,
and Trinity in unity,
neither confusing the persons
nor dividing the divine being.
For the Father is one person,
the Son is another,
and the Holy Spirit is another;
yet the Father and the Son and the Holy Spirit
share one Godhead, equal in glory, co-eternal in majesty.

    path = txt_dir / name
    path.write_text(textwrap.dedent(content).strip() + "\n", encoding="utf-8")
    print("Wrote", path)

write_txt("apostles_creed_en.txt", apostles)
write_txt("nicene_381_en.txt", nicene)
write_txt("athanasian_creed_en.txt", athanasian)
write_txt("chalcedon_definition_en.txt", chalcedon)
# Out:
# Wrote /content/christian-creeds-kb/txt/apostles_creed_en.txt
# Wrote /content/christian-creeds-kb/txt/nicene_381_en.txt
# Wrote /content/christian-creeds-kb/txt/athanasian_creed_en.txt
# Wrote /content/christian-creeds-kb/txt/chalcedon_definition_en.txt

# %% [markdown]
# ## 🔹Cell 3 – Create a minimal README and LICENSE

# %%
readme = f"""# Christian Creeds KB (English)

This repository contains plain-text English versions of four classic Christian creeds,
intended for use in knowledge bases, embeddings, and theological NLP experiments.

Included creeds:

- Apostles' Creed
- Niceno-Constantinopolitan Creed (381) – “Nicene Creed”
- Athanasian Creed (Quicumque vult)
- Definition of Chalcedon (451)

Each creed is provided as a simple UTF-8 `.txt` file under `txt/`, with no markup.

These texts are paraphrased from public-domain formulations of the ancient creeds.

## Use in research

If you use this repo in research, please cite the original historical sources and,
if relevant, the FACTR dissertation project that prepared this corpus.

"""

license_text = """CC0 1.0 Universal (Public Domain Dedication)

To the extent possible under law, the contributors have waived all copyright
and related or neighboring rights to the texts in this repository.

You can copy, modify, distribute and perform the work, even for commercial
purposes, all without asking permission.
"""

(REPO_DIR / "README.md").write_text(readme, encoding="utf-8")
(REPO_DIR / "LICENSE").write_text(license_text, encoding="utf-8")

print("Wrote README.md and LICENSE")
# Out:
# Wrote README.md and LICENSE

# %% [markdown]
# ## 🔹 Cell 4 – Initialise git and make the first commit
# This assumes you’ve already created an empty repo christian-creeds-kb under your GitHub account.

# %%
# %%bash
# cd /content/christian-creeds-kb
#
# if [ ! -d ".git" ]; then
#   git init
# fi
#
# git config user.name  "$GITHUB_USERNAME"
# git config user.email "$GITHUB_EMAIL"
#
# git add .
# git commit -m "Initial commit: four Christian creeds in txt format"
# Out:
# Initialized empty Git repository in /content/christian-creeds-kb/.git/
# [master (root-commit) 8deb078] Initial commit: four Christian creeds in txt format
#  6 files changed, 220 insertions(+)
#  create mode 100644 LICENSE
#  create mode 100644 README.md
#  create mode 100644 txt/apostles_creed_en.txt
#  create mode 100644 txt/athanasian_creed_en.txt
#  create mode 100644 txt/chalcedon_definition_en.txt
#  create mode 100644 txt/nicene_381_en.txt
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>

# %% [markdown]
# ### 🔹 Cell 5 – Connect to GitHub and push (using secrets)

# %%
# %%bash
# set -e
# cd /content/christian-creeds-kb
#
# # Set remote (if not present). We do NOT echo the URL to avoid leaking the token.
# if ! git remote | grep -q origin; then
#   git remote add origin "https://$GITHUB_USERNAME:$GITHUB_TOKEN@github.com/$GITHUB_USERNAME/$REPO_NAME.git" >/dev/null 2>&1
# fi
#
# git branch -M main
# git push -u origin main
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/LukmaanViscomi/christian-creeds-kb.git
# To https://github.com/lukmaanViscomi/christian-creeds-kb.git
#  * [new branch]      main -> main
